# %%
import pytesseract
from ultralytics import YOLO
import cv2
import openpyxl
import os
import sqlite3
from ultralytics.utils.plotting import Annotator
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pytesseract
#       2 from ultralytics import YOLO
#       3 import cv2
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pytesseract\__init__.py:2
#       1 # flake8: noqa: F401
# ----> 2 from .pytesseract import ALTONotSupported
#       3 from .pytesseract import get_languages
#       4 from .pytesseract import get_tesseract_version
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pytesseract\pytesseract.py:29
#      27 from packaging.version import parse
#      28 from packaging.version import Version
# ---> 29 from PIL import Image
#      32 tesseract_cmd = 'tesseract'
#      34 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:114
#     112 USE_CFFI_ACCESS = False
#     113 try:
# --> 114     import cffi
#     115 except ImportError:
#     116     cffi = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\cffi\__init__.py:4
#       1 __all__ = ['FFI', 'VerificationError', 'VerificationMissing', 'CDefError',
#       2            'FFIError']
# ----> 4 from .api import FFI
#       5 from .error import CDefError, FFIError, VerificationError, VerificationMissing
#       6 from .error import PkgConfigError
#
# File ~\AppData\Roaming\Python\Python312\site-packages\cffi\api.py:2
#       1 import sys, types
# ----> 2 from .lock import allocate_lock
#       3 from .error import CDefError
#       4 from . import model
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:991, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1087, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1187, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
pip install pytesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in c:\users\user\appdata\roaming\python\python312\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\user\appdata\roaming\python\python312\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pytesseract) (10.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# pip istall ultralytics

# %%
from platform import python_version

print(python_version())
# Out:
# 3.11.5

# %%
# Function to create the table if it doesn't exist
def create_table():
    # Connect to the SQLite database
    conn = sqlite3.connect("numberplate.db")
    # Create a cursor object to execute SQL statements
    c = conn.cursor()
    # Create the "vehicles" table with two columns: "vehicle_number" and "bike_image_path"
    # The "IF NOT EXISTS" clause ensures that the table is only created if it doesn't already exist
    c.execute("CREATE TABLE IF NOT EXISTS vehicles (vehicle_number TEXT, bike_image_path TEXT)")
    # Commit the changes to the database
    conn.commit()
    # Close the database connection
    conn.close()

# %%
# Function to insert a record into the "vehicles" table
def insert_record(vehicle_number, bike_image_path):
    # Connect to the SQLite database
    conn = sqlite3.connect("numberplate.db")
    # Create a cursor object to execute SQL statements
    c = conn.cursor()
    # Insert the record into the "vehicles" table using parameterized SQL statement
    c.execute("INSERT INTO vehicles VALUES (?, ?)", (vehicle_number, bike_image_path))
    # Commit the changes to the database
    conn.commit()
    # Close the database connection
    conn.close()

# %%
# workbook = openpyxl.Workbook()
# worksheet = workbook.active

# %%
# def write_to_excel(text, image_path):
#     worksheet.append([text, image_path])
#     workbook.save("C:/Users/PRAJWAL M/Registration_Plate_Recognition - Copy/Book1.xlsx")

# %%
# # Initialize YOLO models
# person_bike_model = YOLO(r"C:/Users/PRAJWAL M/Desktop/main_model/300epoch.pt")
# helmet_model = YOLO(r"C:/Users/PRAJWAL M/Desktop/bike-helmet model/300epoch_bh.pt")
# number_plate_model = YOLO(r"C:/Users/PRAJWAL M/Desktop/vehicle model/300epochv.pt")

# %%
# Initialize YOLO models
person_bike_model = YOLO(r"C:\Users\User\OneDrive\Desktop\Final project\person_bike_model.pt")
helmet_model = YOLO(r"C:\Users\User\OneDrive\Desktop\Final project\helmet_model.pt")
number_plate_model = YOLO(r"C:\Users\User\OneDrive\Desktop\Final project\number_plate_model.pt")

# %%
# Set up Tesseract OCR
pytesseract.pytesseract.tesseract_cmd = r"C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
#Check OCR
image_path = "C:/Users/PRAJWAL M/Desktop/images (3).jpg"
frame = cv2.imread(image_path)
text = pytesseract.image_to_string(frame)
# cv2.imshow("window",frame)
print(text)
# Out:
# 66
#
# The advance of
# technology is
# based on
# making it fitin
# so that you
# don’t rally
# even notice it,
# soit’ pat of
# everyday ite

# %%
#tesseract ocr alternative
# import easyocr

# reader = easyocr.Reader(['en'])
# extract_info = reader.readtext(image_path)

# for el in extract_info:
#    print(el)

# %%
output_dir = r"C:/Users/PRAJWAL M/Registration_Plate_Recognition - Copy/output"  # Directory to save the output images for image folder

# %%
output_dir1 = r"C:/Users/PRAJWAL M/Registration_Plate_Recognition - Copy/newoutput"  # Directory to save the output images for video input

# %%
#model test
# person_bike_results = person_bike_model.predict(img, show=True, save=True)
# h_results = helmet_model.predict(img, show=True, save=True)
# n_results = number_plate_model.predict(img, show=True, save=True)
# Out:
# 0: 416x352 1 person_bike, 551.9ms
# Speed: 12.4ms preprocess, 551.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict20
#
# 0: 416x352 1 Without Helmet, 450.8ms
# Speed: 3.0ms preprocess, 450.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict21
#
# 0: 416x352 2 License_Plates, 454.1ms
# Speed: 3.5ms preprocess, 454.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict22

# %%
import os

# Path to the folder containing images
input_folder = "C:\Users\User\OneDrive\Desktop\Final project\otest\otest\otest"


# Get a list of all image files in the input folder
image_files = [os.path.join(input_folder, file) for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

# Process each image in the folder
for image_file in image_files:
    # Load the image
    img = cv2.imread(image_file)

    # Process frame
    #img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Detect person on a bike
    person_bike_results = person_bike_model.predict(img, show=True, save=True)
    
    # Process each detection result
    for r in person_bike_results:
        boxes = r.boxes
        # Filter detections for person on a bike
        for box in boxes:
            cls = box.cls
            print(person_bike_model.names[int(cls)], person_bike_model.names[int(cls)] == "person_bike")
            if person_bike_model.names[int(cls)] == "person_bike":
                # Crop person on a bike image
                x1, y1, x2, y2 = box.xyxy[0]
                person_bike_image = img[int(y1):int(y2), int(x1):int(x2)]

                # Detect helmet on the person
                helmet_results = helmet_model.predict(person_bike_image, show=True, save=True)

                # Process each helmet detection result
                for hr in helmet_results:
                    h_boxes = hr.boxes
                    # Filter detections for no helmet
                    for h_bo in h_boxes:
                        h_cls = h_bo.cls
                        if not helmet_model.names[int(h_cls)] == "With Helmet" :
                            # Extract number plate from the person bike image
                            number_plate_results = number_plate_model.predict(person_bike_image, show=True, save=True)

                            # Process each number plate detection result
                            for npr in number_plate_results:
                                np_boxes = npr.boxes
                                # Filter detections for number plate
                                for np_box in np_boxes:
                                    np_cls = np_box.cls
                                    print(number_plate_model.names[int(np_cls)])
                                    if number_plate_model.names[int(np_cls)] == "License_Plate":
                                        # Crop number plate image
                                        np_x1, np_y1, np_x2, np_y2 = np_box.xyxy[0]
                                        number_plate_image = person_bike_image[int(np_y1):int(np_y2),
                                                             int(np_x1):int(np_x2)]
                                        # Save the cropped images of persons on bikes with violations
                                        output_file = f"person_bike_violation_{os.path.basename(image_file)}"
                                        output_path = os.path.join(output_dir, output_file)
                                        cv2.imwrite(output_path, person_bike_image)

                                        # Save the cropped number plate image
                                        output_file_number_plate = f"number_plate_violation_{os.path.basename(image_file)}"
                                        output_path_number_plate = os.path.join(output_dir, output_file_number_plate)
                                        cv2.imwrite(output_path_number_plate, number_plate_image)
                                        gray = cv2.cvtColor(number_plate_image, cv2.COLOR_BGR2GRAY)
                                        text = pytesseract.image_to_string(gray)
                                        # Example usage
                                        # Create the "vehicles" table if it doesn't exist
                                        create_table()
                                        # Insert two records into the "vehicles" table
                                        insert_record(text, output_path)
                                        # Print the extracted text
                                        print("Number Plate Text:", text)
# Out:
# 0: 416x416 2 person_bikes, 789.6ms
# Speed: 15.7ms preprocess, 789.6ms inference, 18.9ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 54.7ms
# Speed: 2.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 138.5ms
# Speed: 1.0ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x224 2 Without Helmets, 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 (no detections), 186.4ms
# Speed: 1.0ms preprocess, 186.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x224 (no detections), 177.5ms
# Speed: 1.1ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x416 2 person_bikes, 280.1ms
# Speed: 1.9ms preprocess, 280.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 2 License_Plates, 160.5ms
# Speed: 2.1ms preprocess, 160.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x192 2 Without Helmets, 53.0ms
# Speed: 0.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 165.3ms
# Speed: 1.0ms preprocess, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: ADS,
# cu 1163
#
#
# 0: 416x192 1 License_Plate, 178.7ms
# Speed: 0.0ms preprocess, 178.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: ADS,
# cu 1163
#
#
# 0: 288x416 2 person_bikes, 215.2ms
# Speed: 1.2ms preprocess, 215.2ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 1 Without Helmet, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 (no detections), 175.6ms
# Speed: 1.0ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 1 With Helmet, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 320x416 2 person_bikes, 261.8ms
# Speed: 1.0ms preprocess, 261.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 2 Without Helmets, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 147.6ms
# Speed: 1.1ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: | BPS NPI
#
#
# 0: 416x192 1 License_Plate, 185.9ms
# Speed: 1.0ms preprocess, 185.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: | BPS NPI
#
# person_bike True
#
# 0: 416x224 1 Without Helmet, 62.7ms
# Speed: 1.2ms preprocess, 62.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 199.6ms
# Speed: 1.2ms preprocess, 199.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 352x416 3 person_bikes, 264.6ms
# Speed: 1.0ms preprocess, 264.6ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x288 1 Without Helmet, 62.2ms
# Speed: 1.0ms preprocess, 62.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x288 (no detections), 189.0ms
# Speed: 1.1ms preprocess, 189.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 288)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x128 1 With Helmet, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x192 1 With Helmet, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 person_bike, 150.4ms
# Speed: 1.5ms preprocess, 150.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 160.6ms
# Speed: 1.0ms preprocess, 160.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x352 1 person_bike, 251.6ms
# Speed: 2.0ms preprocess, 251.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 1 Without Helmet, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 155.1ms
# Speed: 2.1ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 256x416 2 person_bikes, 217.8ms
# Speed: 1.0ms preprocess, 217.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 2 Without Helmets, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 2 License_Plates, 175.4ms
# Speed: 1.0ms preprocess, 175.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# License_Plate
# Number Plate Text: IER 25271
#
#
# 0: 416x224 2 License_Plates, 179.2ms
# Speed: 1.0ms preprocess, 179.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# License_Plate
# Number Plate Text: IER 25271
#
# person_bike True
#
# 0: 416x192 2 Without Helmets, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 149.3ms
# Speed: 0.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: Ag trad
#
#
# 0: 416x192 1 License_Plate, 150.6ms
# Speed: 0.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: Ag trad
#
#
# 0: 416x384 1 person_bike, 272.0ms
# Speed: 1.0ms preprocess, 272.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 140.4ms
# Speed: 1.3ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x320 1 person_bike, 257.2ms
# Speed: 2.2ms preprocess, 257.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 185.3ms
# Speed: 1.0ms preprocess, 185.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x384 1 person_bike, 243.9ms
# Speed: 1.7ms preprocess, 243.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 2 License_Plates, 164.7ms
# Speed: 1.0ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# License_Plate
# Number Plate Text: 108.28 Eb.HN
#
#
# 0: 416x256 1 person_bike, 191.4ms
# Speed: 1.0ms preprocess, 191.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 With Helmet, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x288 1 person_bike, 199.4ms
# Speed: 1.0ms preprocess, 199.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x256 2 With Helmets, 1 Without Helmet, 60.7ms
# Speed: 1.3ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x256 1 License_Plate, 175.4ms
# Speed: 1.4ms preprocess, 175.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x416 1 person_bike, 297.3ms
# Speed: 2.0ms preprocess, 297.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x256 (no detections), 48.8ms
# Speed: 2.0ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x352 1 person_bike, 239.6ms
# Speed: 1.0ms preprocess, 239.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 158.1ms
# Speed: 1.0ms preprocess, 158.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: N78,
# ‘R6160
#
#
# 0: 416x192 1 person_bike, 157.9ms
# Speed: 1.1ms preprocess, 157.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 118.3ms
# Speed: 1.0ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 320x416 2 person_bikes, 233.6ms
# Speed: 2.2ms preprocess, 233.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 2 Without Helmets, 35.0ms
# Speed: 2.0ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 (no detections), 195.8ms
# Speed: 1.0ms preprocess, 195.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x224 (no detections), 156.4ms
# Speed: 1.1ms preprocess, 156.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x160 4 Without Helmets, 29.7ms
# Speed: 0.0ms preprocess, 29.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 (no detections), 114.4ms
# Speed: 0.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x160 (no detections), 127.6ms
# Speed: 1.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x160 (no detections), 149.7ms
# Speed: 1.0ms preprocess, 149.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x160 (no detections), 123.7ms
# Speed: 1.0ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 352x416 3 person_bikes, 255.5ms
# Speed: 1.0ms preprocess, 255.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 158.4ms
# Speed: 2.0ms preprocess, 158.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x128 1 Without Helmet, 38.0ms
# Speed: 0.0ms preprocess, 38.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x128 (no detections), 118.9ms
# Speed: 1.3ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x160 1 Without Helmet, 33.3ms
# Speed: 0.0ms preprocess, 33.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 (no detections), 126.7ms
# Speed: 1.1ms preprocess, 126.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x192 1 person_bike, 149.5ms
# Speed: 1.0ms preprocess, 149.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 131.8ms
# Speed: 0.0ms preprocess, 131.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: “CH 07 X 1800)
#
#
# 0: 416x320 2 person_bikes, 245.0ms
# Speed: 1.0ms preprocess, 245.0ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x320 1 Without Helmet, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x320 1 License_Plate, 240.9ms
# Speed: 2.0ms preprocess, 240.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: L47B5099
#
# person_bike True
#
# 0: 416x256 1 Without Helmet, 58.4ms
# Speed: 1.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x256 1 License_Plate, 207.2ms
# Speed: 1.0ms preprocess, 207.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: KL 47B 5099
#
#
# 0: 416x160 1 person_bike, 149.8ms
# Speed: 1.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 33.9ms
# Speed: 0.0ms preprocess, 33.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 119.2ms
# Speed: 1.0ms preprocess, 119.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x256 1 person_bike, 174.6ms
# Speed: 1.0ms preprocess, 174.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 (no detections), 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 person_bike, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 32.0ms
# Speed: 1.0ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 134.1ms
# Speed: 1.0ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: Rags
#
#
# 0: 416x288 1 person_bike, 204.7ms
# Speed: 1.0ms preprocess, 204.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 1 Without Helmet, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 161.7ms
# Speed: 1.8ms preprocess, 161.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 person_bike, 152.2ms
# Speed: 1.0ms preprocess, 152.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 42.7ms
# Speed: 0.0ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 155.7ms
# Speed: 1.0ms preprocess, 155.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 person_bike, 161.8ms
# Speed: 1.0ms preprocess, 161.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 Without Helmet, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 1 License_Plate, 139.0ms
# Speed: 1.0ms preprocess, 139.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 person_bike, 155.2ms
# Speed: 1.0ms preprocess, 155.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 143.2ms
# Speed: 0.0ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x224 1 person_bike, 161.8ms
# Speed: 1.0ms preprocess, 161.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 163.3ms
# Speed: 1.0ms preprocess, 163.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x192 1 person_bike, 139.6ms
# Speed: 1.0ms preprocess, 139.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 159.1ms
# Speed: 1.0ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: IKL 47B 5099
#
#
# 0: 416x128 1 person_bike, 104.2ms
# Speed: 2.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x128 1 Without Helmet, 28.9ms
# Speed: 1.0ms preprocess, 28.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x128 1 License_Plate, 114.6ms
# Speed: 1.0ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text: KA 25°
# ‘K 8166
#
#
# 0: 416x192 1 person_bike, 144.4ms
# Speed: 1.0ms preprocess, 144.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 2 License_Plates, 144.0ms
# Speed: 1.3ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 person_bike, 164.8ms
# Speed: 1.4ms preprocess, 164.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x384 1 person_bike, 259.6ms
# Speed: 2.0ms preprocess, 259.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 384)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x320 1 Without Helmet, 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x320 1 License_Plate, 218.0ms
# Speed: 2.1ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 person_bike, 143.9ms
# Speed: 1.0ms preprocess, 143.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 Without Helmet, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 149.2ms
# Speed: 1.0ms preprocess, 149.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 256x416 5 person_bikes, 219.0ms
# Speed: 1.0ms preprocess, 219.0ms inference, 3.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x160 1 With Helmet, 38.2ms
# Speed: 0.0ms preprocess, 38.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x224 2 Without Helmets, 43.0ms
# Speed: 2.3ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 (no detections), 166.4ms
# Speed: 1.0ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x224 (no detections), 162.2ms
# Speed: 1.5ms preprocess, 162.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 1 Without Helmet, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 170.4ms
# Speed: 1.0ms preprocess, 170.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 1 With Helmet, 34.4ms
# Speed: 1.0ms preprocess, 34.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x128 1 With Helmet, 35.1ms
# Speed: 0.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 128)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 256x416 4 person_bikes, 183.5ms
# Speed: 2.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 2 Without Helmets, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 (no detections), 155.2ms
# Speed: 1.0ms preprocess, 155.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x224 (no detections), 158.4ms
# Speed: 1.0ms preprocess, 158.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 2 Without Helmets, 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 149.3ms
# Speed: 1.0ms preprocess, 149.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x192 (no detections), 139.5ms
# Speed: 0.0ms preprocess, 139.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 2 Without Helmets, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 1 License_Plate, 133.0ms
# Speed: 1.2ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x192 1 License_Plate, 147.2ms
# Speed: 0.0ms preprocess, 147.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x160 1 Without Helmet, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 (no detections), 150.0ms
# Speed: 1.0ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 320x416 1 person_bike, 233.3ms
# Speed: 1.4ms preprocess, 233.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 2 Without Helmets, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 170.7ms
# Speed: 1.0ms preprocess, 170.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 416x224 1 License_Plate, 173.4ms
# Speed: 0.0ms preprocess, 173.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 288x416 3 person_bikes, 238.9ms
# Speed: 1.0ms preprocess, 238.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x256 1 With Helmet, 57.3ms
# Speed: 1.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x224 1 With Helmet, 1 Without Helmet, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 174.1ms
# Speed: 1.1ms preprocess, 174.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x160 1 With Helmet, 36.4ms
# Speed: 0.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 256x416 1 person_bike, 207.5ms
# Speed: 1.2ms preprocess, 207.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 1 With Helmet, 1 Without Helmet, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x224 1 License_Plate, 147.1ms
# Speed: 1.0ms preprocess, 147.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# License_Plate
# Number Plate Text:
#
# 0: 256x416 3 person_bikes, 171.4ms
# Speed: 1.0ms preprocess, 171.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x224 1 With Helmet, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x192 1 With Helmet, 35.0ms
# Speed: 2.1ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x160 1 With Helmet, 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 224x416 3 person_bikes, 202.7ms
# Speed: 1.3ms preprocess, 202.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x320 1 With Helmet, 1 Without Helmet, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x320 (no detections), 235.0ms
# Speed: 2.0ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x192 2 With Helmets, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x192 1 Without Helmet, 38.4ms
# Speed: 1.1ms preprocess, 38.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x192 (no detections), 141.4ms
# Speed: 1.0ms preprocess, 141.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 256x416 4 person_bikes, 172.7ms
# Speed: 1.0ms preprocess, 172.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x192 1 With Helmet, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x160 1 With Helmet, 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
# person_bike True
#
# 0: 416x160 1 Without Helmet, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x160 (no detections), 133.6ms
# Speed: 1.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
# person_bike True
#
# 0: 416x96 1 Without Helmet, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 96)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17
#
# 0: 416x96 (no detections), 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 96)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict18
#
# 0: 416x256 1 person_bike, 193.8ms
# Speed: 1.0ms preprocess, 193.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict16
# person_bike True
#
# 0: 416x288 1 With Helmet, 64.9ms
# Speed: 1.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
# Results saved to C:\Users\PRAJWAL M\runs\detect\predict17

# %%
# video_capture = cv2.VideoCapture("C:/Users/PRAJWAL M/Desktop/testing/VID_20240322_135640.mp4")  
video_capture = cv2.VideoCapture("C:/Users/PRAJWAL M/Desktop/Untitled video - Made with Clipchamp.mp4")
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    # Process frame
    #img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Detect person on a bike
    person_bike_results = person_bike_model.predict(frame)

    # Process each detection result
    for r in person_bike_results:
        boxes = r.boxes
        # Filter detections for person on a bike
        for box in boxes:
            cls = box.cls
            print(person_bike_model.names[int(cls)], person_bike_model.names[int(cls)] == "person_bike")
            if person_bike_model.names[int(cls)] == "person_bike":
                # Crop person on a bike image
                x1, y1, x2, y2 = box.xyxy[0]
                person_bike_image = frame[int(y1):int(y2), int(x1):int(x2)]

                # Detect helmet on the person
                helmet_results = helmet_model.predict(person_bike_image)

                # Process each helmet detection result
                for hr in helmet_results:
                    h_boxes = hr.boxes
                    # Filter detections for no helmet
                    for h_bo in h_boxes:
                        h_cls = h_bo.cls
                        if not helmet_model.names[int(h_cls)] == "With Helmet" :
                            # Extract number plate from the person bike image
                            number_plate_results = number_plate_model.predict(person_bike_image)

                            # Process each number plate detection result
                            for npr in number_plate_results:
                                np_boxes = npr.boxes
                                # Filter detections for number plate
                                for np_box in np_boxes:
                                    np_cls = np_box.cls
                                    print(number_plate_model.names[int(np_cls)])
                                    if number_plate_model.names[int(np_cls)] == "License_Plate":
                                        # Crop number plate image
                                        np_x1, np_y1, np_x2, np_y2 = np_box.xyxy[0]
                                        number_plate_image = person_bike_image[int(np_y1):int(np_y2),
                                                             int(np_x1):int(np_x2)]
                                        # Save the cropped number plate image
                                        #output_file = f"person_violation_{image_file}"
                                        output_file = f"person_bike_violation_{os.path.basename(image_file)}"
                                        output_path = os.path.join(output_dir1, output_file)
                                        cv2.imwrite(output_path, person_bike_image)

                                        # Perform OCR on the number plate image
                                        gray = cv2.cvtColor(number_plate_image, cv2.COLOR_BGR2GRAY)
                                        text = pytesseract.image_to_string(gray)
                                        # Example usage
                                        # Create the "vehicles" table if it doesn't exist
                                        create_table()
                                        # Insert two records into the "vehicles" table
                                        insert_record(text, output_path)
                                        # Print the extracted text
                                        print("Number Plate Text:", text)
# Out:
# 0: 256x416 2 person_bikes, 398.7ms
# Speed: 4.3ms preprocess, 398.7ms inference, 1.7ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet,
ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 146.4ms
# Speed: 1.0ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: E
# 16574
#
# person_bike True
#
# 0: 416x288 (no detections), 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 386.3ms
# Speed: 2.2ms preprocess, 386.3ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 86.8ms
# Speed: 3.0ms preprocess, 86.8ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 312.9ms
# Speed: 1.0ms preprocess, 312.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: E
# 16574
#
# person_bike True
#
# 0: 416x288 (no detections), 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 403.1ms
# Speed: 1.5ms preprocess, 403.1ms inference, 2.2ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 91.9ms
# Speed: 2.0ms preprocess, 91.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 331.7ms
# Speed: 1.1ms preprocess, 331.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: KADSE
# T6574
#
# person_bike True
#
# 0: 416x288 (no detections), 115.0ms
# Speed: 2.2ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 402.2ms
# Speed: 2.3ms preprocess, 402.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 92.3ms
# Speed: 2.1ms preprocess, 92.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 317.4ms
# Speed: 2.0ms preprocess, 317.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: aKADSE
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 411.5ms
# Speed: 2.0ms preprocess, 411.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 81.6ms
# Speed: 1.0ms preprocess, 81.6ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 306.9ms
# Speed: 2.0ms preprocess, 306.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: KAD SE
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 102.4ms
# Speed: 2.0ms preprocess, 102.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 398.5ms
# Speed: 2.0ms preprocess, 398.5ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 298.6ms
# Speed: 2.6ms preprocess, 298.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: KAS SE
# | T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 389.2ms
# Speed: 2.0ms preprocess, 389.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 303.4ms
# Speed: 1.0ms preprocess, 303.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 98.8ms
# Speed: 2.0ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 393.2ms
# Speed: 2.0ms preprocess, 393.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 95.6ms
# Speed: 2.6ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 341.6ms
# Speed: 1.5ms preprocess, 341.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 402.2ms
# Speed: 1.0ms preprocess, 402.2ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 89.4ms
# Speed: 2.5ms preprocess, 89.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 365.9ms
# Speed: 2.0ms preprocess, 365.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: E
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 101.9ms
# Speed: 2.8ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 269.5ms
# Speed: 2.0ms preprocess, 269.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 185.8ms
# Speed: 1.0ms preprocess, 185.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: KAD SE
# 16574
#
# person_bike True
#
# 0: 416x256 (no detections), 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 172.6ms
# Speed: 1.0ms preprocess, 172.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 167.0ms
# Speed: 1.2ms preprocess, 167.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 194.0ms
# Speed: 2.4ms preprocess, 194.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 2 Without Helmets, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 174.4ms
# Speed: 1.3ms preprocess, 174.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text:
#
# 0: 416x224 1 License_Plate, 168.2ms
# Speed: 1.0ms preprocess, 168.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 199.6ms
# Speed: 1.0ms preprocess, 199.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 179.6ms
# Speed: 1.0ms preprocess, 179.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 180.1ms
# Speed: 1.3ms preprocess, 180.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 2 Without Helmets, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 178.4ms
# Speed: 2.5ms preprocess, 178.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: KAD SE
# T6574
#
#
# 0: 416x224 1 License_Plate, 163.6ms
# Speed: 0.0ms preprocess, 163.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: KAD SE
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 217.8ms
# Speed: 1.3ms preprocess, 217.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 163.8ms
# Speed: 1.1ms preprocess, 163.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: KAGE
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 182.6ms
# Speed: 2.2ms preprocess, 182.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 2 Without Helmets, 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 152.6ms
# Speed: 1.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: a
# T6574
#
#
# 0: 416x224 1 License_Plate, 146.7ms
# Speed: 1.1ms preprocess, 146.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: a
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 163.6ms
# Speed: 1.0ms preprocess, 163.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 2 Without Helmets, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 157.5ms
# Speed: 1.0ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: [ SE
# T6574
#
#
# 0: 416x224 1 License_Plate, 153.9ms
# Speed: 1.0ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: [ SE
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 176.9ms
# Speed: 1.4ms preprocess, 176.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x224 1 Without Helmet, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 224)
#
# 0: 416x224 1 License_Plate, 177.2ms
# Speed: 2.1ms preprocess, 177.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 224)
# License_Plate
# Number Plate Text: 53E
# | T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 186.7ms
# Speed: 1.0ms preprocess, 186.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 37.7ms
# Speed: 1.4ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 168.6ms
# Speed: 0.0ms preprocess, 168.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text: [ La
# T6574
#
# person_bike True
#
# 0: 416x256 (no detections), 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 157.7ms
# Speed: 1.0ms preprocess, 157.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 157.5ms
# Speed: 1.2ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# ...
# Speed: 1.4ms preprocess, 137.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 181.3ms
# Speed: 1.0ms preprocess, 181.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 129.4ms
# Speed: 1.2ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.0ms
# Speed: 2.1ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 207.9ms
# Speed: 1.0ms preprocess, 207.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 141.9ms
# Speed: 1.0ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 230.4ms
# Speed: 2.0ms preprocess, 230.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 107.8ms
# Speed: 1.0ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 164.2ms
# Speed: 1.0ms preprocess, 164.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 148.1ms
# Speed: 1.0ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 189.0ms
# Speed: 1.0ms preprocess, 189.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 140.0ms
# Speed: 1.1ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 3 person_bikes, 211.3ms
# Speed: 1.0ms preprocess, 211.3ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 138.8ms
# Speed: 1.3ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 58.2ms
# Speed: 1.4ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# person_bike True
#
# 0: 416x288 (no detections), 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 165.6ms
# Speed: 1.0ms preprocess, 165.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 166.8ms
# Speed: 1.3ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 3 person_bikes, 182.4ms
# Speed: 1.0ms preprocess, 182.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 156.0ms
# Speed: 1.3ms preprocess, 156.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# person_bike True
#
# 0: 416x288 (no detections), 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 3 person_bikes, 204.2ms
# Speed: 2.0ms preprocess, 204.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.9ms
# Speed: 1.3ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# person_bike True
#
# 0: 416x288 (no detections), 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 3 person_bikes, 196.6ms
# Speed: 2.0ms preprocess, 196.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 118.7ms
# Speed: 1.0ms preprocess, 118.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# person_bike True
#
# 0: 416x288 (no detections), 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 187.7ms
# Speed: 1.0ms preprocess, 187.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 162.6ms
# Speed: 1.2ms preprocess, 162.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 46.3ms
# Speed: 0.0ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 176.5ms
# Speed: 2.0ms preprocess, 176.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 161.7ms
# Speed: 1.0ms preprocess, 161.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 3 person_bikes, 161.3ms
# Speed: 1.0ms preprocess, 161.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 136.4ms
# Speed: 1.2ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
# person_bike True
#
# 0: 416x288 (no detections), 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 288)
#
# 0: 256x416 2 person_bikes, 164.4ms
# Speed: 2.0ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 142.2ms
# Speed: 1.1ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 197.1ms
# Speed: 2.0ms preprocess, 197.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 143.2ms
# Speed: 2.1ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 44.4ms
# Speed: 2.2ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 188.7ms
# Speed: 2.0ms preprocess, 188.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 129.9ms
# Speed: 1.0ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 202.2ms
# Speed: 1.0ms preprocess, 202.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 142.3ms
# Speed: 1.5ms preprocess, 142.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 184.5ms
# Speed: 1.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 140.0ms
# Speed: 1.1ms preprocess, 140.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 206.5ms
# Speed: 1.0ms preprocess, 206.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 34.5ms
# Speed: 1.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 170.3ms
# Speed: 1.0ms preprocess, 170.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 190.3ms
# Speed: 1.0ms preprocess, 190.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x192 1 Without Helmet, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
#
# 0: 416x192 1 License_Plate, 173.6ms
# Speed: 1.0ms preprocess, 173.6ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 192)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 201.3ms
# Speed: 1.0ms preprocess, 201.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 33.7ms
# Speed: 1.2ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 140.9ms
# Speed: 1.4ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 195.1ms
# Speed: 1.0ms preprocess, 195.1ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 129.3ms
# Speed: 1.3ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 48.3ms
# Speed: 2.3ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
#
# 0: 256x416 2 person_bikes, 176.2ms
# Speed: 1.0ms preprocess, 176.2ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
#
# 0: 416x160 1 Without Helmet, 38.4ms
# Speed: 1.0ms preprocess, 38.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 160)
#
# 0: 416x160 1 License_Plate, 128.8ms
# Speed: 1.0ms preprocess, 128.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 160)
# License_Plate
# Number Plate Text:
# person_bike True
#
# 0: 416x256 (no detections), 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 256)
# WARNING ⚠️ 'source' is missing. Using 'source=C:\Users\PRAJWAL M\AppData\Roaming\Python\Python311\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\PRAJWAL M\AppData\Roaming\Python\Python311\site-packages\ultralytics\assets\bus.jpg: 416x320 1 person_bike, 203.5ms
# image 2/2 C:\Users\PRAJWAL M\AppData\Roaming\Python\Python311\site-packages\ultralytics\assets\zidane.jpg: 256x416 2 person_bikes, 210.7ms
# Speed: 2.2ms preprocess, 207.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 416)
# person_bike True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 21
#      18 if person_bike_model.names[int(cls)] == "person_bike":
#      19     # Crop person on a bike image
#      20     x1, y1, x2, y2 = box.xyxy[0]
# ---> 21     person_bike_image = frame[int(y1):int(y2), int(x1):int(x2)]
#      23     # Detect helmet on the person
#      24     helmet_results = helmet_model.predict(person_bike_image)
#
# TypeError: 'NoneType' object is not subscriptable
